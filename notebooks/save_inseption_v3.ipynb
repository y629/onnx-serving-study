# %% [markdown]
# InceptionV3のモデルをロードしてきて，ONNX形式で保存する．

# %%
import torch
import torchvision

# ダミー入力作成
dummy_input = torch.randn(1, 3, 299, 299)
# 学習済みモデルのロード
model = torchvision.models.inception_v3(pretrained=True)

# %%
model
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# 入力と出力名の設定
input_names = [ "actual_input_1" ] + [ "learned_%d" % i for i in range(16) ]
output_names = [ "output1" ]
# ONNX形式で保存
torch.onnx.export(model, dummy_input, "./models/inception_v3.onnx", \
  verbose=True, input_names=input_names, output_names=output_names)
# Out:
# graph(%actual_input_1 : Float(1, 3, 299, 299, strides=[268203, 89401, 299, 1], requires_grad=0, device=cpu),
#       %fc.weight : Float(1000, 2048, strides=[2048, 1], requires_grad=1, device=cpu),
#       %fc.bias : Float(1000, strides=[1], requires_grad=1, device=cpu),
#       %926 : Float(32, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %927 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %929 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %930 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %932 : Float(64, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %933 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %935 : Float(80, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %936 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %938 : Float(192, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cpu),
#       %939 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %941 : Float(64, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %942 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %944 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %945 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %947 : Float(64, 48, 5, 5, strides=[1200, 25, 5, 1], requires_grad=0, device=cpu),
#       %948 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %950 : Float(64, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %951 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %953 : Float(96, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %954 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %956 : Float(96, 96, 3, 3, strides=[864, 9, 3, 1], requires_grad=0, device=cpu),
#       %957 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %959 : Float(32, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %960 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %962 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %963 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %965 : Float(48, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %966 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %968 : Float(64, 48, 5, 5, strides=[1200, 25, 5, 1], requires_grad=0, device=cpu),
#       %969 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %971 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %972 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %974 : Float(96, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %975 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %977 : Float(96, 96, 3, 3, strides=[864, 9, 3, 1], requires_grad=0, device=cpu),
#       %978 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %980 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %981 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %983 : Float(64, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %984 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %986 : Float(48, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %987 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %989 : Float(64, 48, 5, 5, strides=[1200, 25, 5, 1], requires_grad=0, device=cpu),
#       %990 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %992 : Float(64, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %993 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %995 : Float(96, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %996 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %998 : Float(96, 96, 3, 3, strides=[864, 9, 3, 1], requires_grad=0, device=cpu),
#       %999 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1001 : Float(64, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %1002 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %1004 : Float(384, 288, 3, 3, strides=[2592, 9, 3, 1], requires_grad=0, device=cpu),
#       %1005 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1007 : Float(64, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %1008 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %1010 : Float(96, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %1011 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1013 : Float(96, 96, 3, 3, strides=[864, 9, 3, 1], requires_grad=0, device=cpu),
#       %1014 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1016 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1017 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1019 : Float(128, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1020 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1022 : Float(128, 128, 1, 7, strides=[896, 7, 7, 1], requires_grad=0, device=cpu),
#       %1023 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1025 : Float(192, 128, 7, 1, strides=[896, 7, 1, 1], requires_grad=0, device=cpu),
#       %1026 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1028 : Float(128, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1029 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1031 : Float(128, 128, 7, 1, strides=[896, 7, 1, 1], requires_grad=0, device=cpu),
#       %1032 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1034 : Float(128, 128, 1, 7, strides=[896, 7, 7, 1], requires_grad=0, device=cpu),
#       %1035 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1037 : Float(128, 128, 7, 1, strides=[896, 7, 1, 1], requires_grad=0, device=cpu),
#       %1038 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %1040 : Float(192, 128, 1, 7, strides=[896, 7, 7, 1], requires_grad=0, device=cpu),
#       %1041 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1043 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1044 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1046 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1047 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1049 : Float(160, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1050 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1052 : Float(160, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1053 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1055 : Float(192, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1056 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1058 : Float(160, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1059 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1061 : Float(160, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1062 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1064 : Float(160, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1065 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1067 : Float(160, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1068 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1070 : Float(192, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1071 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1073 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1074 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1076 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1077 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1079 : Float(160, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1080 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1082 : Float(160, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1083 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1085 : Float(192, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1086 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1088 : Float(160, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1089 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1091 : Float(160, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1092 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1094 : Float(160, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1095 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1097 : Float(160, 160, 7, 1, strides=[1120, 7, 1, 1], requires_grad=0, device=cpu),
#       %1098 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %1100 : Float(192, 160, 1, 7, strides=[1120, 7, 7, 1], requires_grad=0, device=cpu),
#       %1101 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1103 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1104 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1106 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1107 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1109 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1110 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1112 : Float(192, 192, 1, 7, strides=[1344, 7, 7, 1], requires_grad=0, device=cpu),
#       %1113 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1115 : Float(192, 192, 7, 1, strides=[1344, 7, 1, 1], requires_grad=0, device=cpu),
#       %1116 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1118 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1119 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1121 : Float(192, 192, 7, 1, strides=[1344, 7, 1, 1], requires_grad=0, device=cpu),
#       %1122 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1124 : Float(192, 192, 1, 7, strides=[1344, 7, 7, 1], requires_grad=0, device=cpu),
#       %1125 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1127 : Float(192, 192, 7, 1, strides=[1344, 7, 1, 1], requires_grad=0, device=cpu),
#       %1128 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1130 : Float(192, 192, 1, 7, strides=[1344, 7, 7, 1], requires_grad=0, device=cpu),
#       %1131 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1133 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1134 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1136 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1137 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1139 : Float(320, 192, 3, 3, strides=[1728, 9, 3, 1], requires_grad=0, device=cpu),
#       %1140 : Float(320, strides=[1], requires_grad=0, device=cpu),
#       %1142 : Float(192, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %1143 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1145 : Float(192, 192, 1, 7, strides=[1344, 7, 7, 1], requires_grad=0, device=cpu),
#       %1146 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1148 : Float(192, 192, 7, 1, strides=[1344, 7, 1, 1], requires_grad=0, device=cpu),
#       %1149 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1151 : Float(192, 192, 3, 3, strides=[1728, 9, 3, 1], requires_grad=0, device=cpu),
#       %1152 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1154 : Float(320, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cpu),
#       %1155 : Float(320, strides=[1], requires_grad=0, device=cpu),
#       %1157 : Float(384, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cpu),
#       %1158 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1160 : Float(384, 384, 1, 3, strides=[1152, 3, 3, 1], requires_grad=0, device=cpu),
#       %1161 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1163 : Float(384, 384, 3, 1, strides=[1152, 3, 1, 1], requires_grad=0, device=cpu),
#       %1164 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1166 : Float(448, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cpu),
#       %1167 : Float(448, strides=[1], requires_grad=0, device=cpu),
#       %1169 : Float(384, 448, 3, 3, strides=[4032, 9, 3, 1], requires_grad=0, device=cpu),
#       %1170 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1172 : Float(384, 384, 1, 3, strides=[1152, 3, 3, 1], requires_grad=0, device=cpu),
#       %1173 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1175 : Float(384, 384, 3, 1, strides=[1152, 3, 1, 1], requires_grad=0, device=cpu),
#       %1176 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1178 : Float(192, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cpu),
#       %1179 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1181 : Float(320, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %1182 : Float(320, strides=[1], requires_grad=0, device=cpu),
#       %1184 : Float(384, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %1185 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1187 : Float(384, 384, 1, 3, strides=[1152, 3, 3, 1], requires_grad=0, device=cpu),
#       %1188 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1190 : Float(384, 384, 3, 1, strides=[1152, 3, 1, 1], requires_grad=0, device=cpu),
#       %1191 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1193 : Float(448, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %1194 : Float(448, strides=[1], requires_grad=0, device=cpu),
#       %1196 : Float(384, 448, 3, 3, strides=[4032, 9, 3, 1], requires_grad=0, device=cpu),
#       %1197 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1199 : Float(384, 384, 1, 3, strides=[1152, 3, 3, 1], requires_grad=0, device=cpu),
#       %1200 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1202 : Float(384, 384, 3, 1, strides=[1152, 3, 1, 1], requires_grad=0, device=cpu),
#       %1203 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %1205 : Float(192, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %1206 : Float(192, strides=[1], requires_grad=0, device=cpu)):
#   %581 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %582 : Float(1, 299, 299, strides=[268203, 299, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%actual_input_1, %581) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:135:0
#   %583 : Float(1, 1, 299, 299, strides=[268203, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[1]](%582) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:135:0
#   %584 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.458}]()
#   %585 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Mul(%583, %584)
#   %586 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-0.03}]()
#   %587 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Add(%585, %586)
#   %588 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %589 : Float(1, 299, 299, strides=[268203, 299, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%actual_input_1, %588) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:136:0
#   %590 : Float(1, 1, 299, 299, strides=[268203, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[1]](%589) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:136:0
#   %591 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.448}]()
#   %592 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Mul(%590, %591)
#   %593 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-0.088}]()
#   %594 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Add(%592, %593)
#   %595 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %596 : Float(1, 299, 299, strides=[268203, 299, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%actual_input_1, %595) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:137:0
#   %597 : Float(1, 1, 299, 299, strides=[268203, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[1]](%596) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:137:0
#   %598 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.45}]()
#   %599 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Mul(%597, %598)
#   %600 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-0.188}]()
#   %601 : Float(1, 1, 299, 299, strides=[89401, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Add(%599, %600)
#   %602 : Float(1, 3, 299, 299, strides=[268203, 89401, 299, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=1](%587, %594, %601) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:138:0
#   %925 : Float(1, 32, 149, 149, strides=[710432, 22201, 149, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%602, %926, %927)
#   %605 : Float(1, 32, 149, 149, strides=[710432, 22201, 149, 1], requires_grad=1, device=cpu) = onnx::Relu(%925) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %928 : Float(1, 32, 147, 147, strides=[691488, 21609, 147, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%605, %929, %930)
#   %608 : Float(1, 32, 147, 147, strides=[691488, 21609, 147, 1], requires_grad=1, device=cpu) = onnx::Relu(%928) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %931 : Float(1, 64, 147, 147, strides=[1382976, 21609, 147, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%608, %932, %933)
#   %611 : Float(1, 64, 147, 147, strides=[1382976, 21609, 147, 1], requires_grad=1, device=cpu) = onnx::Relu(%931) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %612 : Float(1, 64, 73, 73, strides=[341056, 5329, 73, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%611) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:718:0
#   %934 : Float(1, 80, 73, 73, strides=[426320, 5329, 73, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%612, %935, %936)
#   %615 : Float(1, 80, 73, 73, strides=[426320, 5329, 73, 1], requires_grad=1, device=cpu) = onnx::Relu(%934) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %937 : Float(1, 192, 71, 71, strides=[967872, 5041, 71, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%615, %938, %939)
#   %618 : Float(1, 192, 71, 71, strides=[967872, 5041, 71, 1], requires_grad=1, device=cpu) = onnx::Relu(%937) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %619 : Float(1, 192, 35, 35, strides=[235200, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%618) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:718:0
#   %940 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%619, %941, %942)
#   %622 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%940) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %943 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%619, %944, %945)
#   %625 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%943) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %946 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%625, %947, %948)
#   %628 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%946) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %949 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%619, %950, %951)
#   %631 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%949) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %952 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%631, %953, %954)
#   %634 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%952) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %955 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%634, %956, %957)
#   %637 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%955) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %638 : Float(1, 192, 37, 37, strides=[262848, 1369, 37, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%619)
#   %639 : Float(1, 192, 35, 35, strides=[235200, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%638) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:246:0
#   %958 : Float(1, 32, 35, 35, strides=[39200, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%639, %959, %960)
#   %642 : Float(1, 32, 35, 35, strides=[39200, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%958) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %643 : Float(1, 256, 35, 35, strides=[313600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%622, %628, %637, %642) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:254:0
#   %961 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%643, %962, %963)
#   %646 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%961) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %964 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%643, %965, %966)
#   %649 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%964) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %967 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%649, %968, %969)
#   %652 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%967) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %970 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%643, %971, %972)
#   %655 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%970) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %973 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%655, %974, %975)
#   %658 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%973) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %976 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%658, %977, %978)
#   %661 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%976) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %662 : Float(1, 256, 37, 37, strides=[350464, 1369, 37, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%643)
#   %663 : Float(1, 256, 35, 35, strides=[313600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%662) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:246:0
#   %979 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%663, %980, %981)
#   %666 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%979) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %667 : Float(1, 288, 35, 35, strides=[352800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%646, %652, %661, %666) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:254:0
#   %982 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%667, %983, %984)
#   %670 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%982) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %985 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%667, %986, %987)
#   %673 : Float(1, 48, 35, 35, strides=[58800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%985) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %988 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%673, %989, %990)
#   %676 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%988) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %991 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%667, %992, %993)
#   %679 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%991) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %994 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%679, %995, %996)
#   %682 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%994) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %997 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%682, %998, %999)
#   %685 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%997) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %686 : Float(1, 288, 37, 37, strides=[394272, 1369, 37, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%667)
#   %687 : Float(1, 288, 35, 35, strides=[352800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%686) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:246:0
#   %1000 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%687, %1001, %1002)
#   %690 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%1000) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %691 : Float(1, 288, 35, 35, strides=[352800, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%670, %676, %685, %690) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:254:0
#   %1003 : Float(1, 384, 17, 17, strides=[110976, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%691, %1004, %1005)
#   %694 : Float(1, 384, 17, 17, strides=[110976, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1003) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1006 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%691, %1007, %1008)
#   %697 : Float(1, 64, 35, 35, strides=[78400, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%1006) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1009 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%697, %1010, %1011)
#   %700 : Float(1, 96, 35, 35, strides=[117600, 1225, 35, 1], requires_grad=1, device=cpu) = onnx::Relu(%1009) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1012 : Float(1, 96, 17, 17, strides=[27744, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%700, %1013, %1014)
#   %703 : Float(1, 96, 17, 17, strides=[27744, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1012) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %704 : Float(1, 288, 17, 17, strides=[83232, 289, 17, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%691) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:718:0
#   %705 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%694, %703, %704) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:287:0
#   %1015 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%705, %1016, %1017)
#   %708 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1015) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1018 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%705, %1019, %1020)
#   %711 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1018) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1021 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%711, %1022, %1023)
#   %714 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1021) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1024 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%714, %1025, %1026)
#   %717 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1024) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1027 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%705, %1028, %1029)
#   %720 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1027) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1030 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%720, %1031, %1032)
#   %723 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1030) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1033 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%723, %1034, %1035)
#   %726 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1033) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1036 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%726, %1037, %1038)
#   %729 : Float(1, 128, 17, 17, strides=[36992, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1036) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1039 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%729, %1040, %1041)
#   %732 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1039) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %733 : Float(1, 768, 19, 19, strides=[277248, 361, 19, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%705)
#   %734 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%733) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:329:0
#   %1042 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%734, %1043, %1044)
#   %737 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1042) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %738 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%708, %717, %732, %737) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:337:0
#   %1045 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%738, %1046, %1047)
#   %741 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1045) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1048 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%738, %1049, %1050)
#   %744 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1048) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1051 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%744, %1052, %1053)
#   %747 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1051) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1054 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%747, %1055, %1056)
#   %750 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1054) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1057 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%738, %1058, %1059)
#   %753 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1057) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1060 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%753, %1061, %1062)
#   %756 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1060) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1063 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%756, %1064, %1065)
#   %759 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1063) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1066 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%759, %1067, %1068)
#   %762 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1066) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1069 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%762, %1070, %1071)
#   %765 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1069) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %766 : Float(1, 768, 19, 19, strides=[277248, 361, 19, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%738)
#   %767 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%766) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:329:0
#   %1072 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%767, %1073, %1074)
#   %770 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1072) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %771 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%741, %750, %765, %770) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:337:0
#   %1075 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%771, %1076, %1077)
#   %774 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1075) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1078 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%771, %1079, %1080)
#   %777 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1078) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1081 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%777, %1082, %1083)
#   %780 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1081) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1084 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%780, %1085, %1086)
#   %783 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1084) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1087 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%771, %1088, %1089)
#   %786 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1087) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1090 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%786, %1091, %1092)
#   %789 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1090) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1093 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%789, %1094, %1095)
#   %792 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1093) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1096 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%792, %1097, %1098)
#   %795 : Float(1, 160, 17, 17, strides=[46240, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1096) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1099 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%795, %1100, %1101)
#   %798 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1099) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %799 : Float(1, 768, 19, 19, strides=[277248, 361, 19, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%771)
#   %800 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%799) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:329:0
#   %1102 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%800, %1103, %1104)
# ...
#   %822 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1120) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1123 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%822, %1124, %1125)
#   %825 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1123) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1126 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%825, %1127, %1128)
#   %828 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1126) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1129 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%828, %1130, %1131)
#   %831 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1129) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %832 : Float(1, 768, 19, 19, strides=[277248, 361, 19, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%804)
#   %833 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%832) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:329:0
#   %1132 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%833, %1133, %1134)
#   %836 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1132) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %837 : Float(1, 768, 17, 17, strides=[221952, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%807, %816, %831, %836) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:337:0
#   %1135 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%837, %1136, %1137)
#   %840 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1135) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1138 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%840, %1139, %1140)
#   %843 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1138) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1141 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%837, %1142, %1143)
#   %846 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1141) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1144 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 7], pads=[0, 3, 0, 3], strides=[1, 1]](%846, %1145, %1146)
#   %849 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1144) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1147 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 1], pads=[3, 0, 3, 0], strides=[1, 1]](%849, %1148, %1149)
#   %852 : Float(1, 192, 17, 17, strides=[55488, 289, 17, 1], requires_grad=1, device=cpu) = onnx::Relu(%1147) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1150 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%852, %1151, %1152)
#   %855 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1150) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %856 : Float(1, 768, 8, 8, strides=[49152, 64, 8, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[2, 2]](%837) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:718:0
#   %857 : Float(1, 1280, 8, 8, strides=[81920, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%843, %855, %856) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:373:0
#   %1153 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%857, %1154, %1155)
#   %860 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1153) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1156 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%857, %1157, %1158)
#   %863 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1156) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1159 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%863, %1160, %1161)
#   %866 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1159) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1162 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%863, %1163, %1164)
#   %869 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1162) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %870 : Float(1, 768, 8, 8, strides=[49152, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%866, %869) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:407:0
#   %1165 : Float(1, 448, 8, 8, strides=[28672, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%857, %1166, %1167)
#   %873 : Float(1, 448, 8, 8, strides=[28672, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1165) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1168 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%873, %1169, %1170)
#   %876 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1168) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1171 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%876, %1172, %1173)
#   %879 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1171) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1174 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%876, %1175, %1176)
#   %882 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1174) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %883 : Float(1, 768, 8, 8, strides=[49152, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%879, %882) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:415:0
#   %884 : Float(1, 1280, 10, 10, strides=[128000, 100, 10, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%857)
#   %885 : Float(1, 1280, 8, 8, strides=[81920, 64, 8, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%884) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:417:0
#   %1177 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%885, %1178, %1179)
#   %888 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1177) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %889 : Float(1, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%860, %870, %883, %888) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:425:0
#   %1180 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%889, %1181, %1182)
#   %892 : Float(1, 320, 8, 8, strides=[20480, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1180) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1183 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%889, %1184, %1185)
#   %895 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1183) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1186 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%895, %1187, %1188)
#   %898 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1186) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1189 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%895, %1190, %1191)
#   %901 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1189) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %902 : Float(1, 768, 8, 8, strides=[49152, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%898, %901) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:407:0
#   %1192 : Float(1, 448, 8, 8, strides=[28672, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%889, %1193, %1194)
#   %905 : Float(1, 448, 8, 8, strides=[28672, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1192) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1195 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%905, %1196, %1197)
#   %908 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1195) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1198 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%908, %1199, %1200)
#   %911 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1198) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %1201 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%908, %1202, %1203)
#   %914 : Float(1, 384, 8, 8, strides=[24576, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1201) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %915 : Float(1, 768, 8, 8, strides=[49152, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%911, %914) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:415:0
#   %916 : Float(1, 2048, 10, 10, strides=[204800, 100, 10, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 1, 1, 0, 0, 1, 1], value=0.](%889)
#   %917 : Float(1, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%916) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:417:0
#   %1204 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%917, %1205, %1206)
#   %920 : Float(1, 192, 8, 8, strides=[12288, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Relu(%1204) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1296:0
#   %921 : Float(1, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%892, %902, %915, %920) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:425:0
#   %922 : Float(1, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=1, device=cpu) = onnx::GlobalAveragePool(%921) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1168:0
#   %923 : Float(1, 2048, strides=[2048, 1], requires_grad=1, device=cpu) = onnx::Flatten[axis=1](%922) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torchvision/models/inception.py:189:0
#   %output1 : Float(1, 1000, strides=[1000, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%923, %fc.weight, %fc.bias) # /Users/ishimotoyuuta/miniforge3/envs/kaggle/lib/python3.9/site-packages/torch/nn/functional.py:1847:0
#   return (%output1)
